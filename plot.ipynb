# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data_cwq_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [54, 57, 59, 60],
    'Ours': [56.5, 57.5, 63.5, 63.1],
}
data_cwq_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [52, 56, 58, 60],
    'Ours': [53.2, 61.3, 62.3, 63.1],
}
data_webqsp_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [72, 73.5, 75, 76.2],
    'Ours': [74.5, 77.8, 79.2, 79.0],
}
data_webqsp_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [62.5, 66.73, 74.3, 76.2],
    'Ours': [64, 68, 72, 79.3],
}

# Convert the dictionaries to DataFrames
df_cwq_depths = pd.DataFrame(data_cwq_depths)
df_cwq_widths = pd.DataFrame(data_cwq_widths)
df_webqsp_depths = pd.DataFrame(data_webqsp_depths)
df_webqsp_widths = pd.DataFrame(data_webqsp_widths)


# Now that we have our DataFrames, we can plot them using seaborn as before
# Adjusting the figure size to accommodate all four plots
plt.figure(figsize=(12, 3))

plt.subplot(1, 4, 1)  # Positioning the first plot
sns.lineplot(x='Depths', y='ToG', data=df_cwq_depths,
             marker='o', label='ToG', lw=2)
sns.lineplot(x='Depths', y='Ours', data=df_cwq_depths,
             marker='o', label='Ours', lw=2)
plt.title('CWQ', fontsize=14, fontweight='bold')
plt.ylabel('Hits@1', fontsize=13, fontweight='bold')
plt.xlabel('Depths', fontsize=13, fontweight='bold')
plt.legend()

plt.subplot(1, 4, 2)  # Positioning the second plot
sns.lineplot(x='Widths', y='ToG', data=df_cwq_widths,
             marker='o', label='ToG', lw=2)
sns.lineplot(x='Widths', y='Ours', data=df_cwq_widths,
             marker='o', label='Ours', lw=2)
plt.title('CWQ', fontsize=14, fontweight='bold')
plt.ylabel('Hits@1', fontsize=13, fontweight='bold')
plt.xlabel('Widths', fontsize=13, fontweight='bold')
plt.legend()

plt.subplot(1, 4, 3)  # Positioning the third plot
sns.lineplot(x='Depths', y='ToG', data=df_webqsp_depths,
             marker='o', label='ToG', lw=2)
sns.lineplot(
    x='Depths', y='Ours', data=df_webqsp_depths, marker='o', label='Ours', lw=2
)
plt.title('WebQSP', fontsize=14, fontweight='bold')
plt.ylabel('Hits@1', fontsize=13, fontweight='bold')
plt.xlabel('Depths', fontsize=13, fontweight='bold')
plt.legend()

plt.subplot(1, 4, 4)  # Positioning the fourth plot
sns.lineplot(x='Widths', y='ToG', data=df_webqsp_widths,
             marker='o', label='ToG', lw=2)
sns.lineplot(
    x='Widths', y='Ours', data=df_webqsp_widths, marker='o', label='Ours', lw=2
)
plt.title('WebQSP', fontsize=14, fontweight='bold')
plt.ylabel('Hits@1', fontsize=13, fontweight='bold')
plt.xlabel('Widths', fontsize=13, fontweight='bold')
plt.legend()

plt.tight_layout()
# Save the figure to a file
plt.savefig('exp_depth_width.pdf')

# Display the plots
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid", palette="Paired")

# Data Definitions
data_cwq_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [54, 57, 59, 60],
    'Ours': [56.5, 57.5, 63.5, 63.1],
}
data_cwq_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [52, 56, 58, 60],
    'Ours': [53.2, 61.3, 62.3, 63.1],
}
data_webqsp_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [72, 73.5, 75, 76.2],
    'Ours': [74.5, 77.8, 79.2, 79.0],
}
data_webqsp_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [62.5, 66.73, 74.3, 76.2],
    'Ours': [64, 68, 72, 79.3],
}

# Convert the dictionaries to DataFrames
df_cwq_depths = pd.DataFrame(data_cwq_depths)
df_cwq_widths = pd.DataFrame(data_cwq_widths)
df_webqsp_depths = pd.DataFrame(data_webqsp_depths)
df_webqsp_widths = pd.DataFrame(data_webqsp_widths)


# Plot 1: CWQ Depths
plt.figure(figsize=(4.5, 4))

sns.lineplot(x='Depths', y='ToG', data=df_cwq_depths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Depths', y='Ours', data=df_cwq_depths, marker='o', label='Ours', lw=3)
plt.title('CWQ - Depths', fontsize=20, fontweight='bold')
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Depths', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0.9, 4.1)
plt.ylim(50, 65)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='lower right', fancybox=True, framealpha=0.05)
plt.tight_layout()
plt.savefig('exp_cwq_depths.pdf')
plt.show()

# Plot 2: CWQ Widths
plt.figure(figsize=(4.5, 4))

sns.lineplot(x='Widths', y='ToG', data=df_cwq_widths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Widths', y='Ours', data=df_cwq_widths, marker='o', label='Ours', lw=3)
plt.title('CWQ - Widths', fontsize=20, fontweight='bold')
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Widths',fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0.9, 4.1)
plt.ylim(50, 65)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='lower right', fancybox=True, framealpha=0.05)
plt.tight_layout()
plt.savefig('exp_cwq_widths.pdf')
plt.show()

# Plot 3: WebQSP Depths
plt.figure(figsize=(4.5, 4))

sns.lineplot(x='Depths', y='ToG', data=df_webqsp_depths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Depths', y='Ours', data=df_webqsp_depths, marker='o', label='Ours', lw=3)
plt.title('WebQSP - Depths', fontsize=20, fontweight='bold')
plt.xlim(0.9, 4.1)
plt.ylim(60, 82)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Depths', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='lower right', fancybox=True, framealpha=0.05)
plt.tight_layout()
plt.savefig('exp_webqsp_depths.pdf')
plt.show()

# Plot 4: WebQSP Widths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Widths', y='ToG', data=df_webqsp_widths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Widths', y='Ours', data=df_webqsp_widths, marker='o', label='Ours', lw=3)
plt.title('WebQSP - Widths', fontsize=20, fontweight='bold')
plt.xlim(0.9, 4.1)
plt.ylim(60, 82)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Widths', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='lower right', fancybox=True, framealpha=0.05)
plt.tight_layout()
plt.savefig('exp_webqsp_widths.pdf')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style and palette
sns.set(style="whitegrid", palette="Paired")

# Data Definitions
data_cwq_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [54, 57, 59, 60],
    'Ours': [56.5, 57.5, 63.5, 63.1],
}
data_cwq_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [52, 56, 58, 60],
    'Ours': [53.2, 61.3, 62.3, 63.1],
}
data_webqsp_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [72, 73.5, 75, 76.2],
    'Ours': [74.5, 77.8, 79.2, 79.0],
}
data_webqsp_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [62.5, 66.73, 74.3, 76.2],
    'Ours': [64, 68, 72, 79.3],
}

# Convert the dictionaries to DataFrames
df_cwq_depths = pd.DataFrame(data_cwq_depths)
df_cwq_widths = pd.DataFrame(data_cwq_widths)
df_webqsp_depths = pd.DataFrame(data_webqsp_depths)
df_webqsp_widths = pd.DataFrame(data_webqsp_widths)

# Baseline Values
baseline_cwq_1 = 34.87
baseline_cwq_2 = 43.21
baseline_webqsp_1 = 62.32
baseline_webqsp_2 = 57.42

# Function to Add Baselines
def add_baselines(dataset, baseline1, baseline2):
    paired_palette = sns.color_palette("Paired")
    baseline1_color = paired_palette[3]  # Second last color in the palette
    baseline2_color = paired_palette[-1]  # Last color in the palette
    # plt.axhline(y=baseline1, color=baseline1_color, linestyle='dashdot', linewidth=3, label='Zero-shot')
    plt.axhline(y=baseline2, color=baseline1_color, linestyle='dashdot', linewidth=3.5, label='CoT')

# Plot 1: CWQ Depths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Depths', y='ToG', data=df_cwq_depths, marker='o', label='ToG', lw=3, markersize=10)
sns.lineplot(x='Depths', y='Ours', data=df_cwq_depths, marker='o', label='Ours', lw=3, markersize=10)
add_baselines('CWQ', baseline_cwq_1, baseline_cwq_2)
plt.title('CWQ - Depths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Depths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(40, 65)  # Adjusted to include Baseline 1
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig('figures/exp_cwq_depths.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# Plot 2: CWQ Widths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Widths', y='ToG', data=df_cwq_widths, marker='o', label='ToG', lw=3, markersize=10)
sns.lineplot(x='Widths', y='Ours', data=df_cwq_widths, marker='o', label='Ours', lw=3, markersize=10)
add_baselines('CWQ', baseline_cwq_1, baseline_cwq_2)
plt.title('CWQ - Widths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Widths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(40, 65)  # Adjusted to include Baseline 1
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig('figures/exp_cwq_widths.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# Plot 3: WebQSP Depths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Depths', y='ToG', data=df_webqsp_depths, marker='o', label='ToG', lw=3, markersize=10)
sns.lineplot(x='Depths', y='Ours', data=df_webqsp_depths, marker='o', label='Ours', lw=3, markersize=10)
add_baselines('WebQSP', baseline_webqsp_1, baseline_webqsp_2)
plt.title('WebQSP - Depths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Depths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(50, 82)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig('figures/exp_webqsp_depths.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# Plot 4: WebQSP Widths
plt.figure(figsize=(4.5, 4))

sns.lineplot(x='Widths', y='ToG', data=df_webqsp_widths, marker='o', label='ToG', lw=3, markersize=10)
sns.lineplot(x='Widths', y='Ours', data=df_webqsp_widths, marker='o', label='Ours', lw=3, markersize=10)
add_baselines('WebQSP', baseline_webqsp_1, baseline_webqsp_2)
plt.title('WebQSP - Widths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Widths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(50, 82)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig('figures/exp_webqsp_widths.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

model_name = 'gpt-4-turbo'

# Set Seaborn style and palette
sns.set(style="whitegrid", palette="Paired")

# Data Definitions
data_cwq_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [54, 57, 59, 60],
    'Ours': [56.5, 57.5, 63.5, 63.1],
}
data_cwq_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [52, 56, 58, 60],
    'Ours': [53.2, 61.3, 62.3, 63.1],
}
data_webqsp_depths = {
    'Depths': [1, 2, 3, 4],
    'ToG': [72, 73.5, 75, 76.2],
    'Ours': [74.5, 77.8, 79.2, 79.0],
}
data_webqsp_widths = {
    'Widths': [1, 2, 3, 4],
    'ToG': [62.5, 66.73, 74.3, 76.2],
    'Ours': [64, 68, 72, 79.3],
}

# Convert the dictionaries to DataFrames
df_cwq_depths = pd.DataFrame(data_cwq_depths)
df_cwq_widths = pd.DataFrame(data_cwq_widths)
df_webqsp_depths = pd.DataFrame(data_webqsp_depths)
df_webqsp_widths = pd.DataFrame(data_webqsp_widths)

# Baseline Values
baseline_cwq_1 = 34.87
baseline_cwq_2 = 53.51
baseline_webqsp_1 = 62.32
baseline_webqsp_2 = 72.11

# Function to Add Baselines
def add_baselines(dataset, baseline1, baseline2):
    paired_palette = sns.color_palette("Paired")
    baseline1_color = paired_palette[3]  # Second last color in the palette
    baseline2_color = paired_palette[-1]  # Last color in the palette
    # plt.axhline(y=baseline1, color=baseline1_color, linestyle='dashdot', linewidth=3, label='Zero-shot')
    plt.axhline(y=baseline2, color=baseline1_color, linestyle='dashdot', linewidth=3.5, label='CoT')

# Plot 1: CWQ Depths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Depths', y='ToG', data=df_cwq_depths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Depths', y='Ours', data=df_cwq_depths, marker='o', label='Ours', lw=3)
add_baselines('CWQ', baseline_cwq_1, baseline_cwq_2)
plt.title('CWQ - Depths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Depths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(40, 65)  # Adjusted to include Baseline 1
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig(f'figures/exp_cwq_depths_{model_name}.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# Plot 2: CWQ Widths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Widths', y='ToG', data=df_cwq_widths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Widths', y='Ours', data=df_cwq_widths, marker='o', label='Ours', lw=3)
add_baselines('CWQ', baseline_cwq_1, baseline_cwq_2)
plt.title('CWQ - Widths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Widths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(40, 65)  # Adjusted to include Baseline 1
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig(f'figures/exp_cwq_widths_{model_name}.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# Plot 3: WebQSP Depths
plt.figure(figsize=(4.5, 4))
sns.lineplot(x='Depths', y='ToG', data=df_webqsp_depths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Depths', y='Ours', data=df_webqsp_depths, marker='o', label='Ours', lw=3)
add_baselines('WebQSP', baseline_webqsp_1, baseline_webqsp_2)
plt.title('WebQSP - Depths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Depths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(50, 82)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig(f'figures/exp_webqsp_depths_{model_name}.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# Plot 4: WebQSP Widths
plt.figure(figsize=(4.5, 4))

sns.lineplot(x='Widths', y='ToG', data=df_webqsp_widths, marker='o', label='ToG', lw=3)
sns.lineplot(x='Widths', y='Ours', data=df_webqsp_widths, marker='o', label='Ours', lw=3)
add_baselines('WebQSP', baseline_webqsp_1, baseline_webqsp_2)
plt.title('WebQSP - Widths', fontsize=20)
plt.ylabel('Hits@1', fontsize=20)
plt.xlabel('Widths', fontsize=20)
plt.xticks([1, 2, 3, 4],fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(0.9, 4.1)
plt.ylim(50, 82)
plt.grid(True, which='both', linestyle='--', linewidth=1.5)
plt.legend(fontsize=14, loc='right', fancybox=True, framealpha=0.05)
plt.savefig(f'figures/exp_webqsp_widths_{model_name}.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
data_cwq_depths = {
    'Depths': [1, 2, 3],
    'Vanilla Retriever': [59, 53, 47],
    'Path-RAG': [73, 70, 64],
}

data_webqsp_depths = {
    'Depths': [1, 2],
    'Vanilla Retriever': [67, 59],
    'Path-RAG': [83, 78],
}

# Convert the dictionaries to DataFrames
df_cwq_depths = pd.DataFrame(data_cwq_depths)
df_webqsp_depths = pd.DataFrame(data_webqsp_depths)

df_cwq_depths_long = pd.melt(
    df_cwq_depths, id_vars='Depths', var_name='Group', value_name='Hits@1'
)
df_webqsp_depths_long = pd.melt(
    df_webqsp_depths, id_vars='Depths', var_name='Group', value_name='Hits@1'
)

# Adjusting the figure size to accommodate all four plots
plt.figure(figsize=(4.5, 4.25))

sns.barplot(
    x='Depths', y='Hits@1', hue='Group', data=df_cwq_depths_long, palette='Paired'
)
# plt.title('CWQ', fontsize=18)
plt.xticks([0, 1, 2], ['1', '2', '>=3'], fontsize=16)
plt.yticks(fontsize=16)
plt.ylabel('Coverage Rate (CR) (%)', fontsize=18)
plt.xlabel('Depths', fontsize=18)
plt.ylim(0, 80)

plt.legend(fontsize=14, loc='upper center', fancybox=True, framealpha=0.005, ncol=2, bbox_to_anchor=(0.5, 1.15))

plt.tight_layout()
# Save the figure to a file
plt.savefig('figures/cr_analysis_a.png', dpi=300, bbox_inches='tight')

# Display the plots
plt.show()


plt.figure(figsize=(4.5, 4.25))
# plt.subplot(1, 2, 2)  # Positioning the third plot
sns.barplot(
    x='Depths', y='Hits@1', hue='Group', data=df_webqsp_depths_long, palette='Paired'
)
# plt.title('WebQSP', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.ylabel('Coverage Rate (CR) (%)', fontsize=18)
plt.xlabel('Depths', fontsize=18)
plt.legend(fontsize=14, loc='upper center', fancybox=True, framealpha=0.005, ncol=2, bbox_to_anchor=(0.5, 1.15))

plt.tight_layout()
# Save the figure to a file
plt.savefig('figures/cr_analysis_b.png', dpi=300, bbox_inches='tight')

# Display the plots
plt.show()
